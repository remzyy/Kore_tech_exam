# %%
import json
import pandas as pd

# %%
import pandas as pd

df = pd.read_json('output_notTrue.json')
df=df['records'].apply(pd.Series)

df=df.drop('attributes',axis = 1)
df
# Out:
#      IndividualId             OwnerId                           Email  \
# 0            None  005Dn000002LA8CIAW                   rose@edge.com
# 1            None  005Dn000002LA8CIAW                   sean@edge.com
# 2            None  005Dn000002LA8CIAW          jrogers@burlington.com
# 3            None  005Dn000002LA8CIAW                 pat@pyramid.net
# 4            None  005Dn000002LA8CIAW           a_young@dickenson.com
# ...           ...                 ...                             ...
# 1482         None  005Dn000002M1PFIA0     grace63@adventure-works.com
# 1483         None  005Dn000002M1PFIA0     grace64@adventure-works.com
# 1484         None  005Dn000002M1PFIA0     grace64@adventure-works.com
# 1485         None  005Dn000002M1PFIA0     grace65@adventure-works.com
# 1486         None  005Dn000002M1PFIA0  patricia14@adventure-works.com
#
#      FirstName   LastName                                  MailingStreet  \
# ...

# %%
df.sort_values(['Email', 'Phone'], ascending=True,inplace=True)
df
# Out:
#     IndividualId             OwnerId                        Email  FirstName  \
# 4           None  005Dn000002LA8CIAW        a_young@dickenson.com       Andy
# 12          None  005Dn000002LA8CIAW               agreen@uog.com        Avi
# 14          None  005Dn000002LA8CIAW               ajames@uog.com     Ashley
# 409         None  005Dn000002LA8CIAW  alexa18@adventure-works.com      Alexa
# 612         None  005Dn000002LA8CIAW  alexa19@adventure-works.com      Alexa
# ..           ...                 ...                          ...        ...
# 290         None  005Dn000002LA8CIAW    zoe17@adventure-works.com        Zoe
# 958         None  005Dn000002LA8CIAW    zoe21@adventure-works.com        Zoe
# 302         None  005Dn000002LA8CIAW    zoe22@adventure-works.com        Zoe
# 18          None  005Dn000002LA8CIAW                         None  Siddartha
# 19          None  005Dn000002LA8CIAW                         None       Jake
#
# ...

# %%
df.drop_duplicates(subset='Email', keep='first', inplace=True)
df
# Out:
#     IndividualId             OwnerId                        Email  FirstName  \
# 4           None  005Dn000002LA8CIAW        a_young@dickenson.com       Andy
# 12          None  005Dn000002LA8CIAW               agreen@uog.com        Avi
# 14          None  005Dn000002LA8CIAW               ajames@uog.com     Ashley
# 409         None  005Dn000002LA8CIAW  alexa18@adventure-works.com      Alexa
# 612         None  005Dn000002LA8CIAW  alexa19@adventure-works.com      Alexa
# ..           ...                 ...                          ...        ...
# 133         None  005Dn000002LA8CIAW    zoe16@adventure-works.com        Zoe
# 290         None  005Dn000002LA8CIAW    zoe17@adventure-works.com        Zoe
# 958         None  005Dn000002LA8CIAW    zoe21@adventure-works.com        Zoe
# 302         None  005Dn000002LA8CIAW    zoe22@adventure-works.com        Zoe
# 18          None  005Dn000002LA8CIAW                         None  Siddartha
#
# ...

# %%
df = df.reset_index().rename(columns={'index': 'ID'})

df
# Out:
#        ID IndividualId             OwnerId                        Email  \
# 0       4         None  005Dn000002LA8CIAW        a_young@dickenson.com
# 1      12         None  005Dn000002LA8CIAW               agreen@uog.com
# 2      14         None  005Dn000002LA8CIAW               ajames@uog.com
# 3     409         None  005Dn000002LA8CIAW  alexa18@adventure-works.com
# 4     612         None  005Dn000002LA8CIAW  alexa19@adventure-works.com
# ...   ...          ...                 ...                          ...
# 1473  133         None  005Dn000002LA8CIAW    zoe16@adventure-works.com
# 1474  290         None  005Dn000002LA8CIAW    zoe17@adventure-works.com
# 1475  958         None  005Dn000002LA8CIAW    zoe21@adventure-works.com
# 1476  302         None  005Dn000002LA8CIAW    zoe22@adventure-works.com
# 1477   18         None  005Dn000002LA8CIAW                         None
#
#       FirstName LastName                                      MailingStreet  \
# ...

# %%
df.to_json('finalout.json',orient='records')

# %%
# Create a dictionary to store the unique email IDs
unique_emails = {}

# Loop through the data and add records with unique email IDs to the dictionary
for record in data:
    email = record['email']
    if email not in unique_emails:
        unique_emails[email] = record
    else:
        # If there is already a record with this email, check if the current record has a phone number
        if 'phonenumber' in record:
            # If the current record has a phone number, replace the existing record with it
            unique_emails[email] = record
        else: 
                pass
# Create a list of the unique records with both email IDs and phone numbers
unique_records = [record for record in unique_emails.values() if 'phonenumber' in record]

# Print the unique records
for record in unique_records:
    print(record)

# Write the records with email addresses back to the file
with open('data1.json', 'w') as f:
  json.dump(unique_records, f, indent=4)
# Out:
# {'id': 2, 'email': 'john.doe@gmail.com', 'suffix': 'Mr.', 'First_name': 'John', 'last_name': 'Doe', 'delivery_street': '456 Elm St', 'delivery_city': 'Los Angeles', 'delivery_post_code': '90001', 'delivery_state': 'New York', 'deliver_country': 'USA', 'phonenumber': '+1 555-1235', 'do_not_call': 'False', 'updated_on': '2023-03-09', 'created_on': '2023-03-09'}
# {'id': 3, 'email': 'bob.smith@yahoo.com', 'suffix': None, 'First_name': 'Bob', 'last_name': 'Smith', 'delivery_street': '789 Oak Ave', 'delivery_city': 'Chicago', 'delivery_post_code': '60601', 'delivery_state': 'New York', 'deliver_country': 'USA', 'phonenumber': '+1 555-9012', 'do_not_call': 'False', 'updated_on': '2023-03-09', 'created_on': '2023-03-09'}
# ...

# %%
f = open('data1.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
df = pd.DataFrame(data)
df
# Out:
#    id                 email suffix First_name last_name delivery_street  \
# 0   2    john.doe@gmail.com    Mr.       John       Doe      456 Elm St
# 1   3   bob.smith@yahoo.com   None        Bob     Smith     789 Oak Ave
# 2   4                         Mrs.       Mary   Johnson     234 Pine St
# 3   5  jim.wilson@gmail.com   None        Jim    Wilson   567 Maple Ave
#
#    delivery_city delivery_post_code delivery_state deliver_country  \
# 0    Los Angeles              90001       New York             USA
# 1        Chicago              60601       New York             USA
# 2          Miami              33101       New York             USA
# 3  San Francisco              94101       New York             USA
#
#    phonenumber do_not_call  updated_on  created_on
# 0  +1 555-1235       False  2023-03-09  2023-03-09
# 1  +1 555-9012       False  2023-03-09  2023-03-09
# 2  +1 555-3456       False  2023-03-09  2023-03-09
# 3  +1 555-7890       False  2023-03-09  2023-03-09

# %%
import pandas as pd
import numpy as np
# Load the JSON data into a pandas DataFrame
df = pd.read_json('data1.json')

# Replace blank values with NaN
df['email'] = df['email'].replace('', np.nan)

# Drop all rows where the emailid column is null
df = df.dropna(subset=['email'])
df
# Out:
#    id                 email suffix First_name last_name delivery_street  \
# 0   2    john.doe@gmail.com    Mr.       John       Doe      456 Elm St
# 1   3   bob.smith@yahoo.com   None        Bob     Smith     789 Oak Ave
# 3   5  jim.wilson@gmail.com   None        Jim    Wilson   567 Maple Ave
#
#    delivery_city  delivery_post_code delivery_state deliver_country  \
# 0    Los Angeles               90001       New York             USA
# 1        Chicago               60601       New York             USA
# 3  San Francisco               94101       New York             USA
#
#    phonenumber do_not_call  updated_on  created_on
# 0  +1 555-1235       False  2023-03-09  2023-03-09
# 1  +1 555-9012       False  2023-03-09  2023-03-09
# 3  +1 555-7890       False  2023-03-09  2023-03-09

# %%
# Write the updated DataFrame back to a JSON file
df.to_json('data1.json', orient='records')
